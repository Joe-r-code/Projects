# %%
import os
import pandas as pd

# %%
# !wget https://ftp.ncbi.nlm.nih.gov/genomes/GENOME_REPORTS/prok_representative_genomes.txt
# Out:
# --2023-07-11 07:09:41--  https://ftp.ncbi.nlm.nih.gov/genomes/GENOME_REPORTS/prok_representative_genomes.txt
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.11, 130.14.250.7, 2607:f220:41e:250::11, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 499552 (488K) [text/plain]
# Saving to: ‘prok_representative_genomes.txt’
#
# prok_representative 100%[===================>] 487.84K  1.65MB/s    in 0.3s
#
# 2023-07-11 07:09:42 (1.65 MB/s) - ‘prok_representative_genomes.txt’ saved [499552/499552]

# %%
genome_list = pd.read_csv('prok_representative_genomes.txt', '\t')

genome_list
# Out:
# <ipython-input-10-85bf40ca72e5>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   genome_list = pd.read_csv('prok_representative_genomes.txt', '\t')
#                      #Species/genus  Genomes  \
# 0             Abiotrophia defectiva        1
# 1                 Absiella dolichum        3
# 2            Acaricomes phytoseiuli        1
# 3              Acaryochloris marina        1
# 4     Acetanaerobacterium elongatum        1
# ...                             ...      ...
# 5676          Zunongwangia mangrovi        1
# 5677          Zunongwangia profunda        7
# 5678              Zymobacter palmae        2
# 5679              Zymomonas mobilis       15
# 5680              Zymomonas mobilis       15
#
#                                      Organism name Chromosome RefSeq  \
# 0                 Abiotrophia defectiva ATCC 49176               NaN
# ...
